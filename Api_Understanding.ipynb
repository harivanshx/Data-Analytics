# %% [markdown]
# <a href="https://colab.research.google.com/github/harivanshx/Data-Analytics/blob/main/Api_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing the y finance library in python

# %%
pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
#fetch the stock data
tesla = "TSLA"
tesla_stock = yf.download(tesla)
print(tesla_stock)
# Out:
# /tmp/ipython-input-1820816745.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_stock = yf.download(tesla)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-10-20  447.429993  449.799988  440.609985  443.869995   63719000
# 2025-10-21  442.600006  449.299988  442.049988  445.760010   54412200
# 2025-10-22  438.970001  445.540009  429.000000  443.450012   84023500
# 2025-10-23  448.980011  449.399994  413.899994  420.000000  126709800
# 2025-10-24  433.720001  451.679993  430.170013  446.829987   94727800
# 2025-10-27  452.420013  460.160004  438.690002  439.980011  105867500
# 2025-10-28  460.549988  467.000000  451.600006  454.779999   80185700
# 2025-10-29  461.510010  465.700012  452.649994  462.500000   67983500
# ...

# %%
 ### Data for specific range

tesla_stock = yf.download(tesla,start = "2024-11-18",end = "2025-11-18")
print(tesla_stock)
# Out:
# /tmp/ipython-input-466733411.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_stock = yf.download(tesla,start = "2024-11-18",end = "2025-11-18")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2024-11-18  338.739990  348.549988  330.010010  340.730011  126085600
# 2024-11-19  346.000000  347.380005  332.750000  335.760010   88852500
# 2024-11-20  342.029999  346.600006  334.299988  345.000000   66340700
# 2024-11-21  339.640015  347.989990  335.279999  343.809998   58011700
# 2024-11-22  352.559998  361.529999  337.700012  341.089996   89140700
# ...                ...         ...         ...         ...        ...
# 2025-11-11  439.619995  442.489990  432.359985  439.399994   60533200
# 2025-11-12  430.600006  442.329987  426.559998  442.149994   58513500
# ...

# %%
tesla_stock.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2024-11-18  338.739990  348.549988  330.010010  340.730011  126085600
# 2024-11-19  346.000000  347.380005  332.750000  335.760010   88852500
# 2024-11-20  342.029999  346.600006  334.299988  345.000000   66340700
# 2024-11-21  339.640015  347.989990  335.279999  343.809998   58011700
# 2024-11-22  352.559998  361.529999  337.700012  341.089996   89140700

# %%
tesla_stock.to_csv("tesla_stock.csv")

# %%
tesla_balance_sheet = yf.Ticker("TSLA").balance_sheet
print(tesla_balance_sheet)
# Out:
#                                                     2024-12-31    2023-12-31  \
# Treasury Shares Number                                     NaN  0.000000e+00
# Ordinary Shares Number                            3.216000e+09  3.185000e+09
# Share Issued                                      3.216000e+09  3.185000e+09
# Total Debt                                        1.362300e+10  9.573000e+09
# Tangible Book Value                               7.144300e+10  6.201900e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  3.656300e+10  2.909400e+10
# Other Short Term Investments                      2.042400e+10  1.269600e+10
# Cash And Cash Equivalents                         1.613900e+10  1.639800e+10
# Cash Equivalents                                  1.753000e+09  4.950000e+08
# Cash Financial                                    1.438600e+10  1.590300e+10
#
# ...
